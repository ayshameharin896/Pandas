# %% [markdown]
# <a href="https://colab.research.google.com/github/ayshameharin896/Pandas/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
a=[1,3,2,4,3]
b=pd.Series(a)
print(b)
# Out:
# 0    1
# 1    3
# 2    2
# 3    4
# 4    3
# dtype: int64

# %%
a={"Name":["Aysha","Arathi","Aswathy"],"Age":[26,22,27]}
b=pd.DataFrame(a)
print(b)
# Out:
#       Name  Age
# 0    Aysha   26
# 1   Arathi   22
# 2  Aswathy   27

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd

df = pd.read_csv("BLINKIT TRIAL MEASURES.csv")
print(df)
# Out:
#      <input type="file" id="files-495cb274-a2e9-4a23-b733-f55da10c159a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-495cb274-a2e9-4a23-b733-f55da10c159a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#    campaign_id      campaign_name        date target_audience channel  \
# 0       548299  New User Discount  05-11-2024         Premium     App
# 1       390914    Weekend Special  05-11-2024        Inactive     App
# 2       834385     Festival Offer  05-11-2024        Inactive   Email
# 3       241523         Flash Sale  05-11-2024        Inactive     SMS
# 4       595111   Membership Drive  05-11-2024       New Users   Email
#
#    impressions  clicks  conversions    spend  revenue_generated  roas
# 0         3130     163           78  1431.85            4777.75  3.60
# 1         3925     494           45  4506.34            6238.11  2.98
# 2         7012     370           78  4524.23            2621.00  2.95
# 3         1115     579           86  3622.79            2955.00  2.84
# 4         7172     795           54  2888.99            8951.81  2.22

# %%
df.tail()
# Out:
#    campaign_id          campaign_name        date target_audience  \
# 4       595111       Membership Drive  05-11-2024       New Users
# 5       176344     Category Promotion  05-11-2024        Inactive
# 6       875646  App Push Notification  05-11-2024         Premium
# 7         5516         Email Campaign  05-11-2024         Premium
# 8       989534       Referral Program  05-11-2024       New Users
#
#         channel  impressions  clicks  conversions    spend  revenue_generated  \
# 4         Email         7172     795           54  2888.99            8951.81
# 5           App         4333     421           40  2714.78            6697.88
# 6         Email         4752     937           21  3584.76            9152.99
# 7  Social Media         1559     418           68  1457.88            2156.09
# 8           SMS         3838     911           45  4808.64            8074.17
#
#    roas
# 4  2.22
# 5  3.89
# 6  2.14
# 7  3.92
# 8  1.70

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   campaign_id        9 non-null      int64
#  1   campaign_name      9 non-null      object
#  2   date               9 non-null      object
#  3   target_audience    9 non-null      object
#  4   channel            9 non-null      object
#  5   impressions        9 non-null      int64
#  6   clicks             9 non-null      int64
#  7   conversions        9 non-null      int64
#  8   spend              9 non-null      float64
#  9   revenue_generated  9 non-null      float64
#  10  roas               9 non-null      float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 924.0+ bytes

# %%
df.describe()
# Out:
#          campaign_id  impressions      clicks  conversions        spend  \
# count       9.000000     9.000000    9.000000     9.000000     9.000000
# mean   517474.666667  4092.888889  565.333333    57.222222  3282.251111
# std    340803.306571  2085.753488  264.151945    21.579955  1265.268675
# min      5516.000000  1115.000000  163.000000    21.000000  1431.850000
# 25%    241523.000000  3130.000000  418.000000    45.000000  2714.780000
# 50%    548299.000000  3925.000000  494.000000    54.000000  3584.760000
# 75%    834385.000000  4752.000000  795.000000    78.000000  4506.340000
# max    989534.000000  7172.000000  937.000000    86.000000  4808.640000
#
#        revenue_generated      roas
# count           9.000000  9.000000
# mean         5736.088889  2.915556
# std          2734.794456  0.790634
# min          2156.090000  1.700000
# 25%          2955.000000  2.220000
# 50%          6238.110000  2.950000
# 75%          8074.170000  3.600000
# ...

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd

df = pd.read_excel("BLINKIT MEASURES.xlsx")
print(df)
# Out:
#      <input type="file" id="files-d3d99d0d-edde-45ce-a8bc-777bdb9a5e7b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d3d99d0d-edde-45ce-a8bc-777bdb9a5e7b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head()
# Out:
#    campaign_id      campaign_name       date target_audience channel  \
# 0       548299  New User Discount 2024-11-05         Premium     App
# 1       390914    Weekend Special 2024-11-05        Inactive     App
# 2       834385     Festival Offer 2024-11-05        Inactive   Email
# 3       241523         Flash Sale 2024-11-05        Inactive     SMS
# 4       595111   Membership Drive 2024-11-05       New Users   Email
#
#    impressions  clicks  conversions    spend  revenue_generated  roas
# 0         3130     163           78  1431.85            4777.75  3.60
# 1         3925     494           45  4506.34            6238.11  2.98
# 2         7012     370           78  4524.23            2621.00  2.95
# 3         1115     579           86  3622.79            2955.00  2.84
# 4         7172     795           54  2888.99            8951.81  2.22

# %%
df.tail()
# Out:
#    campaign_id          campaign_name       date target_audience  \
# 4       595111       Membership Drive 2024-11-05       New Users
# 5       176344     Category Promotion 2024-11-05        Inactive
# 6       875646  App Push Notification 2024-11-05         Premium
# 7         5516         Email Campaign 2024-11-05         Premium
# 8       989534       Referral Program 2024-11-05       New Users
#
#         channel  impressions  clicks  conversions    spend  revenue_generated  \
# 4         Email         7172     795           54  2888.99            8951.81
# 5           App         4333     421           40  2714.78            6697.88
# 6         Email         4752     937           21  3584.76            9152.99
# 7  Social Media         1559     418           68  1457.88            2156.09
# 8           SMS         3838     911           45  4808.64            8074.17
#
#    roas
# 4  2.22
# 5  3.89
# 6  2.14
# 7  3.92
# 8  1.70

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   campaign_id        9 non-null      int64
#  1   campaign_name      9 non-null      object
#  2   date               9 non-null      datetime64[ns]
#  3   target_audience    9 non-null      object
#  4   channel            9 non-null      object
#  5   impressions        9 non-null      int64
#  6   clicks             9 non-null      int64
#  7   conversions        9 non-null      int64
#  8   spend              9 non-null      float64
#  9   revenue_generated  9 non-null      float64
#  10  roas               9 non-null      float64
# dtypes: datetime64[ns](1), float64(3), int64(4), object(3)
# memory usage: 924.0+ bytes

# %%
df.describe()
# Out:
#          campaign_id                 date  impressions      clicks  \
# count       9.000000                    9     9.000000    9.000000
# mean   517474.666667  2024-11-05 00:00:00  4092.888889  565.333333
# min      5516.000000  2024-11-05 00:00:00  1115.000000  163.000000
# 25%    241523.000000  2024-11-05 00:00:00  3130.000000  418.000000
# 50%    548299.000000  2024-11-05 00:00:00  3925.000000  494.000000
# 75%    834385.000000  2024-11-05 00:00:00  4752.000000  795.000000
# max    989534.000000  2024-11-05 00:00:00  7172.000000  937.000000
# std    340803.306571                  NaN  2085.753488  264.151945
#
#        conversions        spend  revenue_generated      roas
# count     9.000000     9.000000           9.000000  9.000000
# mean     57.222222  3282.251111        5736.088889  2.915556
# min      21.000000  1431.850000        2156.090000  1.700000
# 25%      45.000000  2714.780000        2955.000000  2.220000
# ...

# %%
df['campaign_name']
# Out:
# 0        New User Discount
# 1          Weekend Special
# 2           Festival Offer
# 3               Flash Sale
# 4         Membership Drive
# 5       Category Promotion
# 6    App Push Notification
# 7           Email Campaign
# 8         Referral Program
# Name: campaign_name, dtype: object

# %%
df[['campaign_id','campaign_name']]
# Out:
#    campaign_id          campaign_name
# 0       548299      New User Discount
# 1       390914        Weekend Special
# 2       834385         Festival Offer
# 3       241523             Flash Sale
# 4       595111       Membership Drive
# 5       176344     Category Promotion
# 6       875646  App Push Notification
# 7         5516         Email Campaign
# 8       989534       Referral Program

# %%
df.loc[0]
# Out:
# campaign_id                       548299
# campaign_name          New User Discount
# date                 2024-11-05 00:00:00
# target_audience                  Premium
# channel                              App
# impressions                         3130
# clicks                               163
# conversions                           78
# spend                            1431.85
# revenue_generated                4777.75
# roas                                 3.6
# Name: 0, dtype: object

# %%
df["salary"]=[2001,2451,5248,2465,1548,12475,3265,2154,2425]
print(df)
# Out:
#    campaign_id          campaign_name       date target_audience  \
# 0       548299      New User Discount 2024-11-05         Premium
# 1       390914        Weekend Special 2024-11-05        Inactive
# 2       834385         Festival Offer 2024-11-05        Inactive
# 3       241523             Flash Sale 2024-11-05        Inactive
# 4       595111       Membership Drive 2024-11-05       New Users
# 5       176344     Category Promotion 2024-11-05        Inactive
# 6       875646  App Push Notification 2024-11-05         Premium
# 7         5516         Email Campaign 2024-11-05         Premium
# 8       989534       Referral Program 2024-11-05       New Users
#
#         channel  impressions  clicks  conversions    spend  revenue_generated  \
# 0           App         3130     163           78  1431.85            4777.75
# 1           App         3925     494           45  4506.34            6238.11
# 2         Email         7012     370           78  4524.23            2621.00
# ...

# %%
df.drop('salary',axis=1)
# Out:
#    campaign_id          campaign_name       date target_audience  \
# 0       548299      New User Discount 2024-11-05         Premium
# 1       390914        Weekend Special 2024-11-05        Inactive
# 2       834385         Festival Offer 2024-11-05        Inactive
# 3       241523             Flash Sale 2024-11-05        Inactive
# 4       595111       Membership Drive 2024-11-05       New Users
# 5       176344     Category Promotion 2024-11-05        Inactive
# 6       875646  App Push Notification 2024-11-05         Premium
# 7         5516         Email Campaign 2024-11-05         Premium
# 8       989534       Referral Program 2024-11-05       New Users
#
#         channel  impressions  clicks  conversions    spend  revenue_generated  \
# 0           App         3130     163           78  1431.85            4777.75
# 1           App         3925     494           45  4506.34            6238.11
# 2         Email         7012     370           78  4524.23            2621.00
# ...

# %%
df.sort_values("clicks")
# Out:
#    campaign_id          campaign_name       date target_audience  \
# 0       548299      New User Discount 2024-11-05         Premium
# 2       834385         Festival Offer 2024-11-05        Inactive
# 7         5516         Email Campaign 2024-11-05         Premium
# 5       176344     Category Promotion 2024-11-05        Inactive
# 1       390914        Weekend Special 2024-11-05        Inactive
# 3       241523             Flash Sale 2024-11-05        Inactive
# 4       595111       Membership Drive 2024-11-05       New Users
# 8       989534       Referral Program 2024-11-05       New Users
# 6       875646  App Push Notification 2024-11-05         Premium
#
#         channel  impressions  clicks  conversions    spend  revenue_generated  \
# 0           App         3130     163           78  1431.85            4777.75
# 2         Email         7012     370           78  4524.23            2621.00
# 7  Social Media         1559     418           68  1457.88            2156.09
# ...

# %%
data={'department':['HR','IT','HR','IT'],'salary':[2000,3000,2500,3500]}
a=pd.DataFrame(data)
print(a.groupby('department').mean())
# Out:
#             salary
# department
# HR          2250.0
# IT          3250.0

# %%
data={'department':['HR','IT','HR','IT'],'salary':[2000,3000,2500,3500]}
a=pd.DataFrame(data)
a['salary'].sum()
# Out:
# np.int64(11000)

# %%
data={'department':['HR','IT','HR','IT'],'salary':[2000,3000,2500,3500]}
a=pd.DataFrame(data)
a['salary'].mean()
# Out:
# np.float64(2750.0)

# %%
data={'department':['HR','IT','HR','IT'],'salary':[2000,3000,2500,3500]}
a=pd.DataFrame(data)
a['salary'].min()
# Out:
# 2000

# %%
data={'department':['HR','IT','HR','IT'],'salary':[2000,3000,2500,3500]}
a=pd.DataFrame(data)
a['salary'].max()
# Out:
# 3500
